# %% [raw]
# Written By: kerrie geil
# Original Development Date: Feb 2025
# Package Requirements:
# Description: removing unnecessary columns from GBIF data to make file smaller

# %%
import pandas as pd

# %%
data_dir=r'C://Users/kerrie/01_data/GBIF/redEaredSliders/'
data_file = '0000795-250218110819086.csv'

out_dir = r'C://Users/kerrie/00_code/repos/DEV_canvas_beginner_py/data/GBIF/'
out_file = 'redEaredSliders_iNaturalist_GBIF_USsouth_2015-2024.csv'

# %% [markdown]
# # load and subset

# %%
# preview layer data in a geodataframe
df = pd.read_csv(data_dir+data_file, sep ='\t')#, 
                 # usecols=['verbatimScientificName','stateProvince','decimalLatitude',
                 #          'decimalLongitude','coordinateUncertaintyInMeters','eventDate'])
df.head()
# Out:
#        gbifID                            datasetKey  \
# 0  5064128588  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 1  5064097434  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 2  5064093865  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 3  5064077884  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 4  5063941995  50c9509d-22c7-4a22-a47d-8c48425ef4a7
#
#                                         occurrenceID   kingdom    phylum  \
# 0  https://www.inaturalist.org/observations/26130...  Animalia  Chordata
# 1  https://www.inaturalist.org/observations/26129...  Animalia  Chordata
# 2  https://www.inaturalist.org/observations/26129...  Animalia  Chordata
# 3  https://www.inaturalist.org/observations/26137...  Animalia  Chordata
# 4  https://www.inaturalist.org/observations/26095...  Animalia  Chordata
#
#         class  order    family      genus            species  ...  \
# 0  Testudines    NaN  Emydidae  Trachemys  Trachemys scripta  ...
# 1  Testudines    NaN  Emydidae  Trachemys  Trachemys scripta  ...
# ...

# %%
# see all column names
df.columns.tolist()
# Out:
# ['gbifID',
#  'datasetKey',
#  'occurrenceID',
#  'kingdom',
#  'phylum',
#  'class',
#  'order',
#  'family',
#  'genus',
#  'species',
#  'infraspecificEpithet',
#  'taxonRank',
#  'scientificName',
#  'verbatimScientificName',
#  'verbatimScientificNameAuthorship',
#  'countryCode',
#  'locality',
#  'stateProvince',
#  'occurrenceStatus',
#  'individualCount',
#  'publishingOrgKey',
#  'decimalLatitude',
#  'decimalLongitude',
#  'coordinateUncertaintyInMeters',
#  'coordinatePrecision',
#  'elevation',
#  'elevationAccuracy',
#  'depth',
#  'depthAccuracy',
#  'eventDate',
#  'day',
#  'month',
#  'year',
#  'taxonKey',
#  'speciesKey',
#  'basisOfRecord',
#  'institutionCode',
#  'collectionCode',
#  'catalogNumber',
#  'recordNumber',
#  'identifiedBy',
#  'dateIdentified',
#  'license',
#  'rightsHolder',
#  'recordedBy',
#  'typeStatus',
#  'establishmentMeans',
#  'lastInterpreted',
#  'mediaType',
#  'issue']

# %%
# finding which field has the scientific name
df.loc[0,['scientificName','verbatimScientificName','verbatimScientificNameAuthorship']]
# Out:
# scientificName                      Trachemys scripta elegans (Wied, 1838)
# verbatimScientificName                           Trachemys scripta elegans
# verbatimScientificNameAuthorship                                       NaN
# Name: 0, dtype: object

# %%
# subset columns

# subset columns 
df = pd.read_csv(data_dir+data_file, sep ='\t', 
                 usecols=['verbatimScientificName','stateProvince','decimalLatitude',
                          'decimalLongitude','coordinateUncertaintyInMeters','eventDate'])
df.head()
# Out:
#       verbatimScientificName stateProvince  decimalLatitude  decimalLongitude  \
# 0  Trachemys scripta elegans         Texas        29.764617        -95.453697
# 1  Trachemys scripta elegans         Texas        28.983560        -96.012085
# 2  Trachemys scripta elegans         Texas        28.983560        -96.012085
# 3  Trachemys scripta elegans         Texas        29.764506        -95.453683
# 4  Trachemys scripta elegans         Texas        32.317042        -95.252815
#
#    coordinateUncertaintyInMeters            eventDate
# 0                           10.0     2024-09-04T16:00
# 1                          228.0     2024-11-09T11:04
# 2                          228.0     2024-11-09T11:05
# 3                           15.0     2024-09-13T13:27
# 4                         1078.0  2024-09-09T12:02:54

# %% [markdown]
# # write file

# %%
df.to_csv(out_dir+out_file, index = None, header=True)
