# %% [raw]
# Written By: kerrie geil
# Original Development Date: Feb 2025
# Package Requirements: geopandas pyogrio
# Description: Subset rivers to make file smaller and make sure the notebook demo river (Yalobusha) is a single object not segments

# %%
import geopandas as gpd

# %%
data_dir=r'C://Users/kerrie/'
orig_dir = '.shp'

# %% [markdown]
# # load and subset

# %%
# idk where the code is that clipped the original file to MS env

# %% [markdown]
# # aggregate segments on Yalobusha

# %%
# gdf_rivers = gpd.read_file("data/natural_earth/rivers/ms_clipped_major_rivers/ms_clipped_major_rivers.shp",
#                            columns=['name','geometry'])

# %%
# one_yalobusha= gdf_rivers.loc[gdf_rivers.name.isin(['Yalobusha'])].dissolve(by='name',as_index=False,sort=False)
# one_yalobusha

# %%
# gdf_rivers = gdf_rivers.loc[~gdf_rivers.name.isin(['Yalobusha'])]
# gdf_rivers.shape

# %%
# gdf_rivers= pd.concat([gdf_rivers,one_yalobusha]).reset_index(drop=True)
# gdf_rivers

# %%
# gdf_rivers.to_file('data/natural_earth/rivers/MS_major_rivers.shp')

# %% [markdown]
# # write file
